# %%
import pandas as pd

# %%
# Read the CSV file
df = pd.read_csv("../Data/DoctorsET.csv")

# %%
df.info
# Out:
# <bound method DataFrame.info of     message_id                       date      sender_id  \
# 0          864  2023-12-18 17:04:02+00:00  1001102021238
# 1          863  2023-11-03 16:14:39+00:00  1001102021238
# 2          862  2023-10-02 16:37:39+00:00  1001102021238
# 3          861  2023-09-16 07:54:32+00:00  1001102021238
# 4          860  2023-09-01 16:16:15+00:00  1001102021238
# 5          859  2023-08-29 17:20:05+00:00  1001102021238
# 6          848  2022-08-02 17:42:08+00:00  1001102021238
# 7          847  2022-06-12 17:15:47+00:00  1001102021238
# 8          846  2022-05-31 17:51:13+00:00  1001102021238
# 9          845  2022-05-20 18:04:53+00:00  1001102021238
# 10         844  2022-05-15 15:59:10+00:00  1001102021238
# 11         843  2022-05-07 18:22:14+00:00  1001102021238
# 15         839  2022-05-06 17:51:05+00:00  1001102021238
# 16         836  2022-05-01 11:13:33+00:00  1001102021238
# 22         830  2022-04-28 05:46:38+00:00  1001102021238
# ...

# %%
df.dtypes

# %%
# 1) Remove rows without any data
df.dropna(how='all', inplace=True)

# %%
# 2) Convert sender_id to string and remove "-"
df['sender_id'] = df['sender_id'].astype(str).str.replace('-', '')

# %%
# 3) Remove rows with empty message column
df = df[df['message'].notnull()]

# %%
df_copy = df.copy()
df_copy.drop_duplicates(inplace=True)

# %%
#standardize Date
df.loc[:, 'date'] = pd.to_datetime(df['date']).dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
#  Numeric field validation
non_numeric_message_ids = df[~df['message_id'].apply(lambda x: pd.to_numeric(x, errors='coerce')).notnull()]
print("Non-numeric message IDs:\n", non_numeric_message_ids)
# Out:
# Non-numeric message IDs:
#  Empty DataFrame
# Columns: [message_id, date, sender_id, message]
# Index: []
